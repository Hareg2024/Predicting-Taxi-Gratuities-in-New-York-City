# %% [markdown]
# # **Automatidata project**

# %% [markdown]
# Purpose : Developing  data-based solution for the New York City Taxi and Limousine Commission (New York City TLC)

# %% [markdown]
# # Inspect and analyze data
#
#
#
# **The purpose** of this project is to investigate and understand the data provided.
#
# **The goal** is to use a dataframe contructed within Python, perform a cursory inspection of the provided dataset
#
# *This phase has three parts:*
#
# **Part 1:** Understand the situation
# * Understand and organize the provided taxi cab dataset and information.
#
# **Part 2:** Understand the data
#
# * Create a pandas dataframe for data learning, future exploratory data analysis (EDA), and statistical activities.
#
# * Compile summary information about the data to inform next steps.
#
# **Part 3:** Understand the variables

# %% [markdown]
# # **Identify data types and relevant variables using Python**

# %% [markdown]
# PACE stage: Plan, Analyze, Construct, and Execute.

# %% [markdown]
# ### **Task 1. Understand the situation**

# %% [markdown]
# The primary goal is to get the data into Python, inspect it, and provide initial observations.

# %% [markdown]
# ### **Task 2a. Build dataframe**

# %%
os.getcwd()
# Out:
# 'e:\\Google Advanced Data Analytics Certificate courses\\Github'

# %%
#Import libraries and packages listed above


import pandas as pd
import numpy as np 
# Load dataset into dataframe
import os
path = "2017_Yellow_Taxi_Trip_Data.csv"
df = pd.read_csv("2017_Yellow_Taxi_Trip_Data.csv")
#df.head()

# %%
# first column need to be rename 
df = df.rename(columns={'Unnamed: 0': 'ID'})
df.head(10)
# Out:
#           ID  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0   24870114         2   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 1   35634249         1   04/11/2017 2:53:28 PM   04/11/2017 3:19:58 PM
# 2  106203690         1   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 3   38942136         2   05/07/2017 1:17:59 PM   05/07/2017 1:48:14 PM
# 4   30841670         2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
# 5   23345809         2   03/25/2017 8:34:11 PM   03/25/2017 8:42:11 PM
# 6   37660487         2   05/03/2017 7:04:09 PM   05/03/2017 8:03:47 PM
# 7   69059411         2   08/15/2017 5:41:06 PM   08/15/2017 6:03:05 PM
# 8    8433159         2   02/04/2017 4:17:07 PM   02/04/2017 4:29:14 PM
# 9   95294817         1   11/10/2017 3:20:29 PM   11/10/2017 3:40:55 PM
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22699 entries, 0 to 22698
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     22699 non-null  int64
#  1   VendorID               22699 non-null  int64
#  2   tpep_pickup_datetime   22699 non-null  object
#  3   tpep_dropoff_datetime  22699 non-null  object
#  4   passenger_count        22699 non-null  int64
#  5   trip_distance          22699 non-null  float64
#  6   RatecodeID             22699 non-null  int64
#  7   store_and_fwd_flag     22699 non-null  object
#  8   PULocationID           22699 non-null  int64
#  9   DOLocationID           22699 non-null  int64
#  10  payment_type           22699 non-null  int64
#  11  fare_amount            22699 non-null  float64
#  12  extra                  22699 non-null  float64
#  13  mta_tax                22699 non-null  float64
# ...

# %%
#remove PM and AM from pick up na drop of time stamp

df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'], format="%m/%d/%Y %I:%M:%S %p")
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'], format="%m/%d/%Y %I:%M:%S %p")

df['tpep_pickup_datetime'].head()
# Out:
# 0   2017-03-25 08:55:43
# 1   2017-04-11 14:53:28
# 2   2017-12-15 07:26:56
# 3   2017-05-07 13:17:59
# 4   2017-04-15 23:32:20
# Name: tpep_pickup_datetime, dtype: datetime64[ns]

# %%
df.describe()
# Out:
#                  ID      VendorID  passenger_count  trip_distance  \
# count  2.269900e+04  22699.000000     22699.000000   22699.000000
# mean   5.675849e+07      1.556236         1.642319       2.913313
# std    3.274493e+07      0.496838         1.285231       3.653171
# min    1.212700e+04      1.000000         0.000000       0.000000
# 25%    2.852056e+07      1.000000         1.000000       0.990000
# 50%    5.673150e+07      2.000000         1.000000       1.610000
# 75%    8.537452e+07      2.000000         2.000000       3.060000
# max    1.134863e+08      2.000000         6.000000      33.960000
#
#          RatecodeID  PULocationID  DOLocationID  payment_type   fare_amount  \
# count  22699.000000  22699.000000  22699.000000  22699.000000  22699.000000
# mean       1.043394    162.412353    161.527997      1.336887     13.026629
# std        0.708391     66.633373     70.139691      0.496211     13.243791
# ...

# %%
import seaborn as sns 
df_cor=df.corr()
sns.heatmap(df_cor,cmap = 'coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# key variable identification:
#     total amount - strongly related to trip distance, tip, toll and fare amount
#     trip distance - strongly related to tip, toll and total amount

# %% [markdown]
# Distributions of each variable
#
# ** The maximum  fare amount = 999.99 which is way larger value than 25 - 75 percent range values -- need a bit of work
# ** There are negative fare amounts -- that doesn't make sense -- need a bit of work , data cleaning
# ** the 25,50,75 percent of trip distance are between 0.99 - 3 miles, but the maximum trip distnace says 33.96 miles. how?
# ** ratecodeID should range from 1 -6 according to data dictionary , how the max says 99??

# %%
# split date stamp into date and time 
df3 = df

# %%
import datetime

df3['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])

df3['dropp off Date'] = df3['tpep_dropoff_datetime'].dt.date
df3['drop off time'] = df['tpep_dropoff_datetime'].dt.time

# %% [markdown]
# ### ** Understand the data - Investigate the variables**

# %%
Trip_distnace = df.sort_values(by=['trip_distance'],ascending=False)
Trip_distnace .head(10)
# Out:
#              ID  VendorID    tpep_pickup_datetime tpep_dropoff_datetime  \
# 9280   51810714         2  06/18/2017 11:33:25 PM   2017-06-19 00:12:38
# 13861  40523668         2   05/19/2017 8:20:21 AM   2017-05-19 09:20:30
# 6064   49894023         2  06/13/2017 12:30:22 PM   2017-06-13 13:37:51
# 10291  76319330         2  09/11/2017 11:41:04 AM   2017-09-11 12:18:58
# 29     94052446         2   11/06/2017 8:30:50 PM   2017-11-07 00:00:00
# 18130  90375786         1   10/26/2017 2:45:01 PM   2017-10-26 16:12:49
# 5792   68023798         2   08/11/2017 2:14:01 PM   2017-08-11 15:17:31
# 15350  77309977         2   09/14/2017 1:44:44 PM   2017-09-14 14:34:29
# 10302  43431843         1   05/15/2017 8:11:34 AM   2017-05-15 09:03:16
# 2592   51094874         2   06/16/2017 6:51:20 PM   2017-06-16 19:41:42
#
#        passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 9280                 2          33.96           5                  N
# ...

# %%
df_useful = df[['trip_distance','fare_amount']]
Trip_distance = df_useful.sort_values(by =['trip_distance'], ascending=False)
Trip_distance
# Out:
#        trip_distance  fare_amount
# 9280           33.96       150.00
# 13861          33.92       200.01
# 6064           32.72       107.00
# 10291          31.95       131.00
# 29             30.83        80.00
# ...              ...          ...
# 2440            0.00         5.50
# 15916           0.00         8.50
# 1350            0.00         2.50
# 246             0.00         2.50
# 17788           0.00         2.50
#
# [22699 rows x 2 columns]

# %% [markdown]
# * The longest mile is 33 miles same as info we get from df.describe()
#
# *  the maximun amount looks the same as df.decribe() value,  999.99
# * the most expesive fare amount is mentioned the least milage 2.6 not the max mile. That is not good implication
#
# * The max trip mile for trip distance sort was 33 and the fare amount was $150 but the maximum fare amount for amount sort is 999.99 for 2.6 mile.not good data , nonsense result. EVen 0 mile shows several fare amount

# %%
Fare_amount= df_useful.sort_values(by =['fare_amount'], ascending=False)
Fare_amount
# Out:
#        trip_distance  fare_amount
# 8476            2.60       999.99
# 20312           0.00       450.00
# 13861          33.92       200.01
# 15474           0.00       200.00
# 12511           0.00       175.00
# ...              ...          ...
# 14714           0.40        -4.00
# 17602           0.46        -4.00
# 11204           0.64        -4.50
# 20698           0.70        -4.50
# 12944           0.17      -120.00
#
# [22699 rows x 2 columns]

# %%
# the last 20 fare amounts 
# Sort the data by total amount and print the bottom 20 values
Fare_amount.tail(20)

#notice for negative fare amounts, fare cannot be negative
# Out:
#        trip_distance  fare_amount
# 5722            0.00          0.0
# 21842          20.40          0.0
# 19067           0.10          0.0
# 22566           0.00          0.0
# 10506           0.00          0.0
# 4402            7.06          0.0
# 314             0.12         -2.5
# 1646            0.04         -2.5
# 10281           0.00         -2.5
# 5758            0.02         -2.5
# 18565           0.10         -3.0
# 4423            0.06         -3.0
# 8204            0.41         -3.5
# 20317           0.24         -3.5
# 5448            0.25         -3.5
# 14714           0.40         -4.0
# 17602           0.46         -4.0
# 11204           0.64         -4.5
# 20698           0.70         -4.5
# 12944           0.17       -120.0

# %%
#the top 20 Fare amounts 

# Sort the data by total amount and print the top 20 values
Fare_amount.head(20)
# Out:
#        trip_distance  fare_amount
# 8476            2.60       999.99
# 20312           0.00       450.00
# 13861          33.92       200.01
# 15474           0.00       200.00
# 12511           0.00       175.00
# 3582            7.30       152.00
# 9280           33.96       150.00
# 16379          25.50       140.00
# 10291          31.95       131.00
# 11269           0.00       120.00
# 1928           12.50       120.00
# 6064           32.72       107.00
# 13621          19.80       105.00
# 908            26.12       100.00
# 6708            0.32       100.00
# 14995          11.89       100.00
# 7281            0.00       100.00
# 11608          23.00        99.50
# 11839           2.70        99.00
# 6878            0.00        98.50

# %%
 ## # How many of each payment type are represented in the data?

df['payment_type'].value_counts()

# just count how many creditcard payments, cash ...etc
# Out:
# 1    15265
# 2     7267
# 3      121
# 4       46
# Name: payment_type, dtype: int64

# %% [markdown]
# According to the data dictionary, the payment method was encoded as follows:
#
# 1 = Credit card
# 2 = Cash
# 3 = No charge
# 4 = Dispute
# 5 = Unknown
# 6 = Voided trip

# %%
# Correct methods to use conditional statments in pandas 
# avg_valueof column_x = df[criteria]['column name_x'].mean()

# What is the average tip for trips paid for with credit card?
Avg_cc_tip = df[df['payment_type']==1]['tip_amount'].mean()

# What is the average tip for trips paid for with cash?
Avg_cash_tip = df[df['payment_type']==2]['tip_amount'].mean()

print('Average cc tip:',round(Avg_cc_tip,2))
print('Average cah tip:',Avg_cash_tip)
# Out:
# Average cc tip: 2.73
# Average cah tip: 0.0

# %%
df.head()
# Out:
#           ID  VendorID    tpep_pickup_datetime tpep_dropoff_datetime  \
# 0   24870114         2   03/25/2017 8:55:43 AM   2017-03-25 09:09:47
# 1   35634249         1   04/11/2017 2:53:28 PM   2017-04-11 15:19:58
# 2  106203690         1   12/15/2017 7:26:56 AM   2017-12-15 07:34:08
# 3   38942136         2   05/07/2017 1:17:59 PM   2017-05-07 13:48:14
# 4   30841670         2  04/15/2017 11:32:20 PM   2017-04-15 23:49:03
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# 1                1           1.80           1                  N
# 2                1           1.00           1                  N
# 3                1           3.70           1                  N
# 4                1           4.37           1                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0           100           231             1         13.0    0.0      0.5
# ...

# %%
# The below code returns wrong amount, it is returning the varage amount of total tips not for the specifies cash or card condition 
# notice : we cannot use for loops + condition for pandas like lists to calculate values. we can use loops with defining functions  


#What is the average tip for trips paid for with credit card?
total_tip_avg = df['tip_amount'].mean()
print('avg_tip_all:', total_tip_avg)

## using for loops returns wrong value
for payment in df['payment_type']:
    if payment==1:
        card_payment=df['total_amount'].mean()
print('paid_amount in card',card_payment)
    
#==> ENTER YOUR CODE HERE
for payment in df['payment_type']==2:
    tip_cash= df['tip_amount'].mean()
print('tip in cash',tip_cash)
# What is the average tip for trips paid for with cash?
# Out:
# avg_tip_all: 1.8357813119520605
# paid_amount in card 16.31050222476416
# tip in cash 1.8357813119520605

# %%
# How many times is each vendor ID represented in the data?
df['VendorID'].value_counts()
# Out:
# 2    12626
# 1    10073
# Name: VendorID, dtype: int64

# %%
# What is the mean total amount for each vendor? make sure u mention numeric only if not --> AttributeError: 'DataFrame' object has no attribute 'grouby'
df.groupby(['VendorID']).mean()[['total_amount']]

# same result-->  df.groupby(['VendorID']).mean(numeric_only=True)[['total_amount']]
# Out:
#           total_amount
# VendorID
# 1            16.298119
# 2            16.320382

# %%
# Filter the total amount for credit card payments only
df_sort = df[['total_amount','trip_distance','tip_amount','payment_type']]
card_only =df_sort[df['payment_type']==1]
df_cc= card_only.sort_values(by='total_amount',ascending=False)
df_cc.head(20)
# Out:
#        total_amount  trip_distance  tip_amount  payment_type
# 8476        1200.29           2.60      200.00             1
# 13861        258.21          33.92       51.64             1
# 12511        233.74           0.00       46.69             1
# 15474        211.80           0.00       11.00             1
# 6064         179.06          32.72       55.50             1
# 3582         152.30           7.30        0.00             1
# 11269        151.82           0.00       20.00             1
# 1928         137.80          12.50        5.00             1
# 6708         126.00           0.32       25.20             1
# 11608        123.30          23.00       10.00             1
# 908          121.56          26.12       15.00             1
# 7281         120.96           0.00       20.16             1
# 18130        119.31          30.50       19.85             1
# 13621        115.94          19.80        8.00             1
# ...

# %%
# Filter the credit-card-only data for passenger count only
# all the time create a condition with--> df2 = df[df['colun_name']=2]
df_card= df[df['payment_type']==1]
df_card['passenger_count'].value_counts()
# Out:
# 1    10977
# 2     2168
# 5      775
# 3      600
# 6      451
# 4      267
# 0       27
# Name: passenger_count, dtype: int64

# %%
# Calculate the average tip amount for each passenger count (credit card payments only)
df_tipcard= df[df['payment_type']==1]
df_tipcard.groupby(['passenger_count']).mean()[['tip_amount', 'payment_type']]
# Out:
#                  tip_amount  payment_type
# passenger_count
# 0                  2.610370           1.0
# 1                  2.714681           1.0
# 2                  2.829949           1.0
# 3                  2.726800           1.0
# 4                  2.607753           1.0
# 5                  2.762645           1.0
# 6                  2.643326           1.0

# %% [markdown]
# ### summary

# %% [markdown]
# Regardles the number passsenger the tip amount is the same for credit card payments
# * The 2 most important variables are the trip distance and fare amount
